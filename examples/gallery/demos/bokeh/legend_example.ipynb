# %% [markdown]
# URL: http://bokeh.pydata.org/en/latest/docs/gallery/legend.html
#
# Most examples work across multiple plotting backends, this example is also available for:
#
# * [Matplotlib - legend_example](../matplotlib/legend_example.ipynb)

# %%
import numpy as np
import holoviews as hv
hv.extension('bokeh')

# %% [markdown]
# ## Defining data

# %%
x = np.linspace(0, 4*np.pi, 100)
y = np.sin(x)

scatter1 = hv.Scatter((x, y), label='sin(x)')
scatter2 = hv.Scatter((x, y*2), label='2*sin(x)')
scatter3 = hv.Scatter((x, y*3), label='3*sin(x)')

# %% [markdown]
# ## Plot

# %%
example1 = scatter1 * scatter2.opts(style=dict(color='orange')) * scatter3.opts(style=dict(color='green'))
example2 = (
    scatter1 * hv.Curve(scatter1) *
    hv.Curve(scatter2).opts(style=dict(line_dash=(4, 4), color='orange')) *
    scatter3.opts(style=dict(line_color='green', marker='square', fill_alpha=0, size=5)) * hv.Curve(scatter3)
)

example1.relabel("Legend Example") + example2.relabel("Another Legend Example")
